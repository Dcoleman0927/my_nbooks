# %%
import pandas as pd
import seaborn as sns

# %%
avocado = pd.read_csv('avocado.csv')
avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocado["Date"] = pd.to_datetime(avocado["Date"])

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
avocado['Date'] = avocado.Date.dt.strftime("%Y")

# %%
avocado.query('Date == 2015 and type == "conventional" and region == "Albany"')
avocado[['Date', 'Total Bags', 'Small Bags']].head(5)
# Out:
#    Date  Total Bags  Small Bags
# 0  2015     8696.87     8603.62
# 1  2015     9505.56     9408.07
# 2  2015     8145.35     8042.21
# 3  2015     5811.16     5677.40
# 4  2015     6183.95     5986.26

# %%
avocado_melted = pd.melt(avocado, id_vars='Date',
                         value_vars=['Total Bags', 'Small Bags'],
                         var_name ='Bags', value_name ='Count')
avocado_melted
# Out:
#        Date        Bags     Count
# 0      2015  Total Bags   8696.87
# 1      2015  Total Bags   9505.56
# 2      2015  Total Bags   8145.35
# 3      2015  Total Bags   5811.16
# 4      2015  Total Bags   6183.95
# ...     ...         ...       ...
# 36493  2018  Small Bags  13066.82
# 36494  2018  Small Bags   8940.04
# 36495  2018  Small Bags   9351.80
# 36496  2018  Small Bags  10919.54
# 36497  2018  Small Bags  11988.14
#
# [36498 rows x 3 columns]

# %%
sns.relplot(data=avocado_melted, kind = 'line', x='Date', y='Count', hue='Bags')
# Out:
# C:\Users\dshuf\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
avocado['Sales Volume'] = pd.qcut(avocado['Total Volume'], 
                                 q=4, 
                                 labels=['Poor', 'Modest', 'Good', 'Excellent'])

# %%
avocado.head(5)
# Out:
#    Unnamed: 0  Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0  2015          1.33      64236.62  1036.74   54454.85   48.16
# 1           1  2015          1.35      54876.98   674.28   44638.81   58.33
# 2           2  2015          0.93     118220.22   794.70  109149.67  130.50
# 3           3  2015          1.08      78992.15  1132.00   71976.41   72.58
# 4           4  2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region Sales Volume
# 0  Albany       Modest
# 1  Albany       Modest
# ...

# %%
sns.countplot(avocado, x='year', hue = 'Sales Volume')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
avocado_melted = pd.melt(avocado, id_vars='Date',
                         value_vars=['Small Bags', 'Large Bags', 'XLarge Bags'],
                         var_name ='Bags', value_name ='Count')
avocado_melted
# Out:
#        Date         Bags    Count
# 0      2015   Small Bags  8603.62
# 1      2015   Small Bags  9408.07
# 2      2015   Small Bags  8042.21
# 3      2015   Small Bags  5677.40
# 4      2015   Small Bags  5986.26
# ...     ...          ...      ...
# 54742  2018  XLarge Bags     0.00
# 54743  2018  XLarge Bags     0.00
# 54744  2018  XLarge Bags     0.00
# 54745  2018  XLarge Bags     0.00
# 54746  2018  XLarge Bags     0.00
#
# [54747 rows x 3 columns]

# %%
sns.relplot(data=avocado_melted, kind='line', x='Date', y='Count', hue='Bags')
# Out:
# C:\Users\dshuf\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Small Bags sell the best
